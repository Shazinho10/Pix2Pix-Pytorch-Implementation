# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
cd "/content/drive/MyDrive/Pix2Pix from scratch/data/train"
# Out:
# /content/drive/MyDrive/Pix2Pix from scratch/data/train

# %%
ls
# Out:
# image_processing.ipynb  train_A/  train_B/  Untitled0.ipynb

# %%
import cv2
import os
import numpy as np

# %%
def remove_non_jpg_files(directory):
    for filename in os.listdir(directory):
        if not filename.endswith((".jpg", ".jpeg")):
            file_path = os.path.join(directory, filename)
            if os.path.isfile(file_path):
                os.remove(file_path)
                print(f"Deleted file: {filename}")

# %%
remove_non_jpg_files("train_B")

# %%
trg_images = [os.path.join("train_B", i) for i in os.listdir("train_B")]

# %%
image = cv2.imread(trg_images[7])
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
stacked_img = np.stack((gray_image,)*3, axis=-1)

# %%
from google.colab.patches import cv2_imshow

# %%
for i in os.listdir("train_B"):
  lst = [i for i in os.listdir("train_A")]
  if i not in lst:
    print(i)

# %%
len(trg_images), len(lst)
# Out:
# (135, 135)
